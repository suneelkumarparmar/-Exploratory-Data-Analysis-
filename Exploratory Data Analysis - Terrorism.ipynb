# %% [markdown]
# Author SUNEEL KUMAR

# %% [markdown]
# DATA SCIENCE AND BUSINESS ANALYTICS INTERN

# %%
#import the Labraries
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)
plt.rcParams['figure.figsize']=[15,10]

# %%
#loading the dateset
df = pd.read_csv('C:\\Users\\GUDO JI\\Downloads\\Global Terrorism - START data\\globalterrorismdb_0718dist.csv', encoding='ISO-8859-1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
#Data infor
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#Data describe 
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#Defined Columns
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
#Rename coloumns 
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'Killed',
     'nwound':'Wounded'},inplace=True)

# %%
df.shape
df.head()
# Out:
#         eventid  Year  Month  day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region                       Region    State  \
# 0  Dominican Republic       2  Central America & Caribbean      NaN
# 1              Mexico       1                North America  Federal
# 2         Philippines       5               Southeast Asia   Tarlac
# 3              Greece       8               Western Europe   Attica
# 4               Japan       4                    East Asia  Fukouka
#
#             City   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]

# %%
year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna = False).sort_index()
sns.histplot(data=df, x = 'Year',element='step', fill=False, kde=True)
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=16)
plt.ylabel('Number of Attacks Each Year',fontsize=16)
plt.title('Attacks In Years',fontsize=26)
plt.show()

# %%
df.groupby("Year")["Wounded","Killed"].sum().plot(kind='bar', stacked=True)
plt.xlabel("Year")
plt.ylabel("Total Casualties")
plt.title("Year wise Casualties")
# Out:
# Text(0.5, 1.0, 'Year wise Casualties')

# %% [markdown]
# at the 2014 the casualties has highest value and 2014 has highest kills and woundeds

# %%
rattack=df["Region"].value_counts()
rattack
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %% [markdown]
# The highest attack value in Middle East North Africe & South Aisa. Australaia & Oceania has lowest attact value

# %%
#Plot Garph
pd.crosstab(df.Year, df.Region).plot(kind='area',stacked=False)
plt.title('Terror Activities Region-wise  Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %% [markdown]
# Middle East along with North Africa and the South Asia Region are the 2 most affected regions from Terror.

# %%
df.groupby("Region")["Wounded","Killed"].sum().plot(kind='bar', stacked=True)
plt.xlabel("Region",fontsize=20)
plt.ylabel("Total Casualties",fontsize=20)
plt.title("Region wise Casualties",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Region wise Casualties')

# %% [markdown]
# Middle East & North Africa have highest have highest casualies .While Central Asia and Australia has the least and no casualty counts.

# %%
cattack=df["Country"].value_counts()[:15]
cattack
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: Country, dtype: int64

# %% [markdown]
# Iraq has highest value and pakistan is second number

# %%
cattack.plot(kind="bar")
plt.xlabel("Country",fontsize=20)
plt.ylabel("Attacks",fontsize=20)
plt.title("Country wise attacks",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Country wise attacks')

# %% [markdown]
# Iraq has number of terror attack as well as pakistan has also

# %%
ciattack=df["City"].value_counts()[1:16]
ciattack
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Bogota           984
# Kirkuk           925
# Beirut           918
# Medellin         848
# Benghazi         840
# Name: City, dtype: int64

# %% [markdown]
# Baghdad has number of terror attack and karachi has higher . i am going to show below garph

# %%
ciattack.plot(kind="bar",color='red')
plt.xlabel("City",fontsize=20)
plt.ylabel("Attacks",fontsize=20)
plt.title("City wise attacks",fontsize=20)
# Out:
# Text(0.5, 1.0, 'City wise attacks')

# %%
ci=df.groupby("City")["Wounded","Killed"].sum().drop("Unknown")
ci.sort_values(by=['Wounded'],ascending=False,inplace=True)
ci[:15].plot(kind="bar")
plt.xlabel("City",fontsize=20)
plt.ylabel("Total Casualties",fontsize=20)
plt.title("City wise total Casualties",fontsize=20)
# Out:
# Text(0.5, 1.0, 'City wise total Casualties')

# %% [markdown]
# Baghdad has the highest terror attack record

# %%
tattack=df["Attacktype"].value_counts()
tattack
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attacktype, dtype: int64

# %% [markdown]
# Above Description showed that attack done by different type equipements/ways .

# %%
df['Attacktype'].value_counts().plot(kind='bar',color='green')
plt.xticks(rotation = 50)
plt.xlabel("Attack Type",fontsize=20)
plt.ylabel("Number of attack",fontsize=20)
plt.title("Name of Attack Type",fontsize=20)
plt.show()

# %%
df[['Attacktype','Killed']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',color=['darkslateblue'])
plt.xticks(rotation=50)
plt.title("Number of Kills ",fontsize=20)
plt.ylabel('Number of people killed',fontsize=20)
plt.xlabel('Attack Type',fontsize=20)
plt.show()

# %%
gattack=df["Group"].value_counts()[1:16]
gattack
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Name: Group, dtype: int64

# %%
gattack.plot(kind="bar")
plt.xlabel("Group",fontsize=20)
plt.ylabel("Attacks",fontsize=20)
plt.title("Group wise attacks",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Group wise attacks')

# %%
dfx=df.groupby("Group")["Wounded","Killed"].sum().drop("Unknown")
dfx.sort_values(by=['Killed'],ascending=False,inplace=True)
dfx[:15].plot(kind="bar")
plt.xlabel("Terror Group Name",fontsize=20)
plt.ylabel("Total Casualties",fontsize=20)
plt.title("Deaths/Woundeds due to Terror Groups",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Deaths/Woundeds due to Terror Groups')

# %%
dfy= df[['Group','Country','Killed']]
dfy= dfy.groupby(['Group','Country'],axis=0).sum().sort_values('Killed',ascending=False).drop('Unknown').reset_index().head(15)
dfy
# Out:
#                                                Group      Country   Killed
# 0        Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                            Taliban  Afghanistan  29269.0
# 2                                         Boko Haram      Nigeria  16917.0
# 3                                  Shining Path (SL)         Peru  11595.0
# 4            Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                         Al-Shabaab      Somalia   8176.0
# 6   Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7        Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# 8                  Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 9                    Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014.0
# 10     Revolutionary Armed Forces of Colombia (FARC)     Colombia   5644.0
# ...

# %%
kills = df.loc[:,'Killed']
woundeds= df.loc[:,'Wounded']
print('Total number of people killed by terror attacks so far:', int(sum(kills.dropna())))
print('Total number of people wounded by terror attacks so far:', int(sum(woundeds.dropna())))
# Out:
# Total number of people killed by terror attacks so far: 411868
# Total number of people wounded by terror attacks so far: 523869

# %%
ttattack=df["Targettype"].value_counts()
ttattack
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Targettype, dtype: int64

# %%
ttattack.plot(kind="bar")
plt.xlabel("Target Type",fontsize=20)
plt.ylabel("Attacks",fontsize=20)
plt.title("Target Type wise attacks",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Target Type wise attacks')

# %%
typeKill = df.pivot_table(columns='Attacktype', values='Killed', aggfunc='sum')
typeKill
# Out:
# Attacktype  Armed Assault  Assassination  Bombing/Explosion  \
# Killed           160297.0        24920.0           157321.0
#
# Attacktype  Facility/Infrastructure Attack  Hijacking  \
# Killed                              3642.0     3718.0
#
# Attacktype  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# Killed                                   4478.0                      24231.0
#
# Attacktype  Unarmed Assault  Unknown
# Killed                880.0  32381.0

# %%
countryKill = df.pivot_table(columns='Country', values='Killed', aggfunc='sum')
countryKill
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# Killed       39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  Azerbaijan  Bahamas  Bahrain  \
# Killed       490.0     37.0       23.0     30.0       258.0      1.0     44.0
#
# Country  Bangladesh  Barbados  Belarus  Belgium  Belize  Benin  Bhutan  \
# Killed       1244.0      76.0     14.0     79.0     3.0    0.0     9.0
#
# Country  Bolivia  Bosnia-Herzegovina  Botswana  Brazil  Brunei  Bulgaria  \
# Killed      42.0                79.0      11.0   203.0     0.0      28.0
#
# Country  Burkina Faso  Burundi  Cambodia  Cameroon  Canada  \
# Killed          134.0   4205.0     543.0    2347.0   365.0
#
# Country  Central African Republic    Chad  Chile   China  Colombia  Comoros  \
# Killed                     1990.0  1119.0  228.0  1008.0   14698.0      1.0
#
# ...

# %% [markdown]
# CONCLUSION / OBSERVATION
# Number of terrorism attacks were increases rapidly after 2010.
#
# Year with the most attacks: 2014
#
# Most of the terrorism attacks succeded and very few attacks failed.
#
# Country mostly effected with terror attacks was 'Iraq'.
#
# City with the most no of attacks is 'Baghdad' all by ISIL.
#
# Middle East & North Africa are the regions with the most attacks.
#
# Taliban Terrorist Group taking the responsibilities of most of their attacks all mostly done using Bombing/Explosion.
#
# Private Citizens & Property, Military and Police are the top 3 mostly identified Targets by the Terror Group
